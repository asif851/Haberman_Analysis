# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('haberman.csv')
df.head()
# Out:
#    age  operation_year  axil_nodes  status
# 0   30              64           1       1
# 1   30              62           3       1
# 2   30              65           0       1
# 3   31              59           2       1
# 4   31              65           4       1

# %% [markdown]
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# Attribute Information:
#
# age-                Age of patient at time of operation
# operation_year-     Patient's year of operation
# axil_nodes-         Number of positive axillary nodes detected
# status-             Survival status
#                     1 = the patient survived 5 years or longer
#                     2 = the patient died within 5 year

# %%
df.shape
# Out:
# (306, 4)

# %%
df.describe()
# Out:
#               age  operation_year  axil_nodes      status
# count  306.000000      306.000000  306.000000  306.000000
# mean    52.457516       62.852941    4.026144    1.264706
# std     10.803452        3.249405    7.189654    0.441899
# min     30.000000       58.000000    0.000000    1.000000
# 25%     44.000000       60.000000    0.000000    1.000000
# 50%     52.000000       63.000000    1.000000    1.000000
# 75%     60.750000       65.750000    4.000000    2.000000
# max     83.000000       69.000000   52.000000    2.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             306 non-null    int64
#  1   operation_year  306 non-null    int64
#  2   axil_nodes      306 non-null    int64
#  3   status          306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
sns.heatmap(df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
df['status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
sns.countplot(x='status',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
sns.displot(data=df, x="age",palette="bright",kind="hist",kde=True,height=5, aspect=1)
# Out:
# /tmp/ipykernel_9207/2780029023.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data=df, x="age",palette="bright",kind="hist",kde=True,height=5, aspect=1)
# /usr/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="age",hue= 'status',palette="bright",kind="hist",kde=True,height=5, aspect=1)
# Out:
# /usr/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="operation_year",palette="bright",kind="hist",kde=True,height=5, aspect=1)
# Out:
# /tmp/ipykernel_9207/1048492325.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data=df, x="operation_year",palette="bright",kind="hist",kde=True,height=5, aspect=1)
# /usr/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="operation_year",hue='status', palette="bright",kind="hist",kde=True,height=5, aspect=1)
# Out:
# /usr/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['axil_nodes'].unique()
# Out:
# array([ 1,  3,  0,  2,  4, 10,  9, 30,  7, 13,  6, 15, 21, 11,  5, 23,  8,
#        20, 52, 14, 19, 16, 12, 24, 46, 18, 22, 35, 17, 25, 28])

# %%
df['axil_nodes'].value_counts()
# Out:
# 0     136
# 1      41
# 3      20
# 2      20
# 4      13
# 6       7
# 7       7
# 8       7
# 5       6
# 9       6
# 13      5
# 14      4
# 11      4
# 10      3
# 15      3
# 22      3
# 23      3
# 19      3
# 12      2
# 20      2
# 30      1
# 21      1
# 52      1
# 16      1
# 24      1
# 46      1
# 18      1
# 35      1
# 17      1
# 25      1
# 28      1
# Name: axil_nodes, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='axil_nodes',data=df)
# Out:
# <Axes: xlabel='axil_nodes', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='axil_nodes',hue='status',data=df)
# Out:
# <Axes: xlabel='axil_nodes', ylabel='count'>
